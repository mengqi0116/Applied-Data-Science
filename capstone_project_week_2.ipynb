# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
#
# ## Table of Contents
#
# 1. Introduction: Business Problem
# 2. Foursquare API Explore Function
# 3. Data
# 4. Methodology
# 5. Analysis
# 6. Results and Discussion
# 7. Conclusion
#
#
# ## Introduction: Business Problem
# In this project we will try to find an optimal location for opening a restraunt in **Amsterdam, Netherlands** near *Central Railway Station*. Our sole sole objective is to find location that is surrounded by least number of restaraunts and is nearest to *Central Railway Station* which is the famous transport center in Europe. Since there are lots of restaurants in this location we will try to detect locations that are not already crowded with restaurants. We are also particularly interested in areas with no restaurants in vicinity. We would also prefer locations as close to  *Central Railway Station* of Amsterdam as possible, assuming that first two conditions are met.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data
#
# Based on the definition of our problem, factors that will influence our decision are:
#
#  - Number of existing restaurants in the neighborhood (any type of restaurant)
#  - Distance of neighborhood from *Central Railway Station of Amsterdam*
#
# We decided to use regularly spaced grid of locations, centered around *Central Railway Station of Amsterdam*, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
#
#  - centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
#  - number of restaurants and their type and location in every neighborhood will be obtained using **Foursquare API**
#  - coordinate of *Central Railway Station of Amsterdam* will be obtained using **Google Maps API geocoding**
#
# Firstly we will do a general exploration using Foursquare API search query of food.
#
# ### Import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_0              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.1.0               |           py36_0         724 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         822 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.1.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.1.0         | 724 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Foursquare Credentials and Version

# %%
CLIENT_ID = 'SYEWADAPWXPOGCEVE32FQSELE4CBCEABDFCQZKRKHS4NGOHE'
CLIENT_SECRET = 'VEDXRHYYJ1S34VOZZDH3APR5F2PHH32R2WUEMPX51AGUKAWL'
VERSION = '20190729'
LIMIT = 100
radius = 4000
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SYEWADAPWXPOGCEVE32FQSELE4CBCEABDFCQZKRKHS4NGOHE
# CLIENT_SECRET:VEDXRHYYJ1S34VOZZDH3APR5F2PHH32R2WUEMPX51AGUKAWL

# %% [markdown]
# #### To get geographical coordinates of Amsterdam Centraal, Netherlands

# %%
address = 'Amsterdam Centraal, Netherlands'

geolocator = Nominatim(user_agent="amsterdam_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("The geographical coordinates of Amsterdam Centraal is {}, {}.".format(latitude, longitude))
# Out:
# The geographical coordinates of Amsterdam Centraal is 52.378901, 4.9005805.

# %% [markdown]
# #### Since we are planning to open a new restaurant, we will use Foursquare API to run a search query of food.

# %%
search_query = 'food'
print(search_query + ' .... OK!')
# Out:
# food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SYEWADAPWXPOGCEVE32FQSELE4CBCEABDFCQZKRKHS4NGOHE&client_secret=VEDXRHYYJ1S34VOZZDH3APR5F2PHH32R2WUEMPX51AGUKAWL&ll=52.378901,4.9005805&v=20190729&query=food&radius=4000&limit=100'

# %% [markdown]
# #### Get data in the form of json file

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d3ef04ca30619002c094a76'},
#  'response': {'venues': [{'id': '504dc9f3e4b00c01095766a0',
#     'name': 'Food Corner',
#     'location': {'address': 'Dam Square',
#      'lat': 52.37352715384458,
#      'lng': 4.893949262019628,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37352715384458,
#        'lng': 4.893949262019628}],
#      'distance': 748,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Dam Square', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5877c5c1e9dad12ac9e9aa0e',
#     'name': 'STACH  food',
#     'location': {'address': '1e Constantijn Huijgens',
#      'crossStreet': 'Overtoom',
#      'lat': 52.36285262494781,
#      'lng': 4.8750427963849585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36285262494781,
#        'lng': 4.8750427963849585}],
#      'distance': 2490,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1e Constantijn Huijgens (Overtoom)',
#       'Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '52d7ec76498e19770b7d649b',
#     'name': 'St. Anny Food',
#     'location': {'address': 'Stormsteeg 8',
#      'lat': 52.37406002111417,
#      'lng': 4.895094687961053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37406002111417,
#        'lng': 4.895094687961053}],
#      'distance': 655,
#      'postalCode': '1012 BD',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Stormsteeg 8', '1012 BD Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4c9f2aa103133704e7ca6fd5',
#     'name': 'Food Center Amsterdam',
#     'location': {'address': 'Jan van Galenstraat 4',
#      'lat': 52.3762512,
#      'lng': 4.8674898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.3762512,
#        'lng': 4.8674898}],
#      'distance': 2267,
#      'postalCode': '1051 KM',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Jan van Galenstraat 4',
#       '1051 KM Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5cbb2697c876c80039d5e8d3',
#     'name': 'The Food Department',
#     'location': {'address': 'Nieuwezijds Voorburgwal 182',
#      'lat': 52.373764,
#      'lng': 4.890815,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.373764,
#        'lng': 4.890815}],
#      'distance': 876,
#      'postalCode': '1012 SJ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Nieuwezijds Voorburgwal 182',
#       '1012 SJ Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '545894791'},
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '52a3050011d2ae60be6128a0',
#     'name': 'STACH Food',
#     'location': {'address': 'Haarlemmerstraat 150',
#      'lat': 52.38139046900278,
#      'lng': 4.889510748454523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.38139046900278,
#        'lng': 4.889510748454523}],
#      'distance': 801,
#      'postalCode': '1013 EZ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Haarlemmerstraat 150',
#       '1013 EZ Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4b3633ddf964a520093125e3',
#     'name': 'PLAYERS Food & Drinks',
#     'location': {'address': 'Kleine Gartmanplantsoen 25',
#      'crossStreet': 'at Leidsekruisstraat',
#      'lat': 52.36311062437967,
#      'lng': 4.88399986967089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36311062437967,
#        'lng': 4.88399986967089}],
#      'distance': 2087,
#      'postalCode': '1017 RP',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Kleine Gartmanplantsoen 25 (at Leidsekruisstraat)',
#       '1017 RP Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '72089692'},
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4ad9d80cf964a520311b21e3',
#     'name': 'Homemade - Fresh Food & Drinks',
#     'location': {'address': 'Singel 447',
#      'crossStreet': 'Amsterdam',
#      'lat': 52.36729984225847,
#      'lng': 4.890536069869995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36729984225847,
#        'lng': 4.890536069869995}],
#      'distance': 1460,
#      'postalCode': '1012 WP',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Singel 447 (Amsterdam)',
#       '1012 WP Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '50a8eeb6e4b0740a188b900d',
#     'name': 'Halal Food',
#     'location': {'address': 'Damrak',
#      'lat': 52.375248690725584,
#      'lng': 4.895654631033615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.375248690725584,
#        'lng': 4.895654631033615}],
#      'distance': 526,
#      'cc': 'NL',
#      'neighborhood': 'Stadsdeel Centrum',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Damrak', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d10b941735',
#       'name': 'Falafel Restaurant',
#       'pluralName': 'Falafel Restaurants',
#       'shortName': 'Falafel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5c24d2a0e4c459002c9c4e72',
#     'name': 'Vegan Junk Food Bar',
#     'location': {'lat': 52.36639117639653,
#      'lng': 4.891562814497817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36639117639653,
#        'lng': 4.891562814497817}],
#      'distance': 1521,
#      'postalCode': '1017 BE',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1017 BE Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '53ede5e9498e5c7f3c3f79e7',
#     'name': 'STACH food',
#     'location': {'address': 'Nieuwe Hoogstraat 1A',
#      'crossStreet': 'Kloveniersburgwal 37',
#      'lat': 52.371004437786475,
#      'lng': 4.898924662635418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.371004437786475,
#        'lng': 4.898924662635418}],
#      'distance': 886,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Nieuwe Hoogstraat 1A (Kloveniersburgwal 37)',
#       'Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5300c685498ea24a97eca220',
#     'name': "Lavinia's Good Food",
#     'location': {'address': 'Kerkstraat 176',
#      'lat': 52.363244995455375,
#      'lng': 4.889804362194895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.363244995455375,
#        'lng': 4.889804362194895}],
#      'distance': 1890,
#      'postalCode': '1017 GT',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Kerkstraat 176', '1017 GT Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '58dfd4cd5e789619b56c2c6f',
#     'name': 'STACH food',
#     'location': {'address': 'Heiligeweg',
#      'crossStreet': 'Singel',
#      'lat': 52.36739867526189,
#      'lng': 4.889987150625499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36739867526189,
#        'lng': 4.889987150625499}],
#      'distance': 1468,
#      'postalCode': '1012 WP',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Heiligeweg (Singel)',
#       '1012 WP Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '59c28c2d28122f7d4f9a2dcc',
#     'name': 'Vegan Junk Food Bar',
#     'location': {'address': 'Marie Heinekenplein 9-10',
#      'lat': 52.35710688038956,
#      'lng': 4.8911839546897795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.35710688038956,
#        'lng': 4.8911839546897795}],
#      'distance': 2508,
#      'postalCode': '1072 MN',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Marie Heinekenplein 9-10',
#       '1072 MN Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5afc0bbee96d0c002cf60ad8',
#     'name': 'Food Truck Festival',
#     'location': {'lat': 52.37780665984518,
#      'lng': 4.894720226809498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37780665984518,
#        'lng': 4.894720226809498}],
#      'distance': 416,
#      'postalCode': '1101 BA',
#      'cc': 'NL',
#      'neighborhood': 'Zuidoost',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1101 BA Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5b5cb614f1936e002cecf06a',
#     'name': 'Maiko Fusion Food',
#     'location': {'address': '12 Nieuwe Hoogstraat',
#      'lat': 52.37071,
#      'lng': 4.899535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37071,
#        'lng': 4.899535}],
#      'distance': 914,
#      'postalCode': '1011 HE',
#      'cc': 'NL',
#      'neighborhood': 'Stadsdeel Centrum',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['12 Nieuwe Hoogstraat',
#       '1011 HE Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4f01a13fa69d45461f322a0b',
#     'name': 'Peace love & food',
#     'location': {'lat': 52.3778654648589,
#      'lng': 4.8965558240611315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.3778654648589,
#        'lng': 4.8965558240611315}],
#      'distance': 296,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4b6ea5d6f964a52037c52ce3',
#     'name': 'WEr Bar & Food',
#     'location': {'lat': 52.3777670962978,
#      'lng': 4.8961687088012695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.3777670962978,
#        'lng': 4.8961687088012695}],
#      'distance': 325,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '581f016e6401964ad59334d5',
#     'name': 'Tutto Food',
#     'location': {'lat': 52.376558,
#      'lng': 4.896295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.376558,
#        'lng': 4.896295}],
#      'distance': 390,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '53ad6ebb498eeba73df6a0e6',
#     'name': 'Street Food@&Samhoud|Places',
#     'location': {'lat': 52.376271,
#      'lng': 4.905959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.376271,
#        'lng': 4.905959}],
#      'distance': 468,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4b62b673f964a520fd4f2ae3',
#     'name': 'Delicious Food',
#     'location': {'address': 'Westerstraat 24',
#      'lat': 52.37886250071695,
#      'lng': 4.885653102751318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37886250071695,
#        'lng': 4.885653102751318}],
#      'distance': 1014,
#      'postalCode': '1015 MJ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Westerstraat 24',
#       '1015 MJ Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '51264af8e4b088014d6bf8ed',
#     'name': 'STACH food',
#     'location': {'address': 'Nieuwe Spiegelstraat 52',
#      'crossStreet': 'Kerkstraat',
#      'lat': 52.36339434933195,
#      'lng': 4.888619169692225,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36339434933195,
#        'lng': 4.888619169692225}],
#      'distance': 1908,
#      'postalCode': '1017 DG',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Nieuwe Spiegelstraat 52 (Kerkstraat)',
#       '1017 DG Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5399a331498e07c13458bd97',
#     'name': 'Vinnies | good. home. food.',
#     'location': {'address': 'Nieuwezijds Kolk 33',
#      'crossStreet': 'Nieuwezijds Voorburgwal',
#      'lat': 52.37630598958503,
#      'lng': 4.89374757212803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37630598958503,
#        'lng': 4.89374757212803}],
#      'distance': 546,
#      'postalCode': '1012 PV',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Nieuwezijds Kolk 33 (Nieuwezijds Voorburgwal)',
#       '1012 PV Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4f37fc49e4b0d408a506d3e5',
#     'name': 'Food Village',
#     'location': {'lat': 52.37439596700289,
#      'lng': 4.891385024811137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37439596700289,
#        'lng': 4.891385024811137}],
#      'distance': 801,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '556c0f9f498e06a27baae1bb',
#     'name': "'cause BEER loves FOOD",
#     'location': {'address': 'Lange Leidsedwarsstraat 4',
#      'crossStreet': 'Leidsegracht',
#      'lat': 52.365665332355995,
#      'lng': 4.882143373821471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.365665332355995,
#        'lng': 4.882143373821471}],
#      'distance': 1934,
#      'postalCode': '1017 NL',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Lange Leidsedwarsstraat 4 (Leidsegracht)',
#       '1017 NL Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#       'name': 'Beer Bar',
#       'pluralName': 'Beer Bars',
#       'shortName': 'Beer Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '450698396'},
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '549a9e09498e4c9f529e775a',
#     'name': 'Food Crib',
#     'location': {'lat': 52.35920835340153,
#      'lng': 4.882927834890713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.35920835340153,
#        'lng': 4.882927834890713}],
#      'distance': 2499,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4ce584a93598b1f7f78b688d',
#     'name': 'Thai Food',
#     'location': {'lat': 52.37278930198581,
#      'lng': 4.89998179188437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37278930198581,
#        'lng': 4.89998179188437}],
#      'distance': 681,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4c824ca4e602b1f7249f9a7a',
#     'name': 'New Food Fair',
#     'location': {'address': 'Haarlemmerstraat 99-117',
#      'lat': 52.38061492117297,
#      'lng': 4.891651558137505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.38061492117297,
#        'lng': 4.891651558137505}],
#      'distance': 636,
#      'postalCode': '1013',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Haarlemmerstraat 99-117',
#       '1013 Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '50cdcd6ae4b05e62d00d8f58',
#     'name': 'Asian Food Festival',
#     'location': {'lat': 52.3724250793457,
#      'lng': 4.900631904602051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.3724250793457,
#        'lng': 4.900631904602051}],
#      'distance': 720,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4c76a794ff1fb60c1c91f9a7',
#     'name': 'Foodware',
#     'location': {'address': 'Westerstraat',
#      'crossStreet': 'Noordermarkt',
#      'lat': 52.37843102404252,
#      'lng': 4.883399926301942,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37843102404252,
#        'lng': 4.883399926301942}],
#      'distance': 1168,
#      'postalCode': '1016 MN',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Westerstraat (Noordermarkt)',
#       '1016 MN Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4f253130e4b006e5c2eb7979',
#     'name': 'Asian Food Market',
#     'location': {'lat': 52.37248370353377,
#      'lng': 4.8995486559957575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37248370353377,
#        'lng': 4.8995486559957575}],
#      'distance': 717,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '57a384f1498e39ed4d9933db',
#     'name': 'Seoul Food',
#     'location': {'address': 'Kinkerstraat 73',
#      'lat': 52.367094917809574,
#      'lng': 4.871659791954687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.367094917809574,
#        'lng': 4.871659791954687}],
#      'distance': 2364,
#      'postalCode': '1053 DG',
#      'cc': 'NL',
#      'neighborhood': 'Stadsdeel West',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Kinkerstraat 73',
#       '1053 DG Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5a0006cb2aff310a9f675da7',
#     'name': 'Free Food Tour Amsterdam',
#     'location': {'address': 'Dam',
#      'lat': 52.37285496133094,
#      'lng': 4.893355050589889,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37285496133094,
#        'lng': 4.893355050589889}],
#      'distance': 833,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Dam', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '56aa371be4b08b9a8d573520',
#       'name': 'Tour Provider',
#       'pluralName': 'Tour Providers',
#       'shortName': 'Tour Provider',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4a2707c8f964a520c78e1fe3',
#     'name': 'New King',
#     'location': {'address': 'Zeedijk 115-117',
#      'crossStreet': 'Molensteeg',
#      'lat': 52.373592111315155,
#      'lng': 4.9002842900895525,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.373592111315155,
#        'lng': 4.9002842900895525}],
#      'distance': 591,
#      'postalCode': '1012 AV',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Zeedijk 115-117 (Molensteeg)',
#       '1012 AV Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '537b6634498edb1da558d87e',
#     'name': 'STACH food',
#     'location': {'address': 'Admiraal de Ruijterweg 77',
#      'lat': 52.3714254477452,
#      'lng': 4.8600170570429,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.3714254477452,
#        'lng': 4.8600170570429}],
#      'distance': 2879,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Admiraal de Ruijterweg 77',
#       'Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4bccb642fb84c9b608e4203e',
#     'name': 'Pazzi Italian Slow Food',
#     'location': {'address': '1ste Looiersdwarsstraat 4',
#      'lat': 52.36929558897549,
#      'lng': 4.880814409211811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36929558897549,
#        'lng': 4.880814409211811}],
#      'distance': 1716,
#      'postalCode': '1016 VM',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1ste Looiersdwarsstraat 4',
#       '1016 VM Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '58d17c840b7e937dfcef7f34',
#     'name': 'Simz Exotic Food',
#     'location': {'address': 'Prinsenstraat',
#      'lat': 52.377843,
#      'lng': 4.886823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.377843,
#        'lng': 4.886823}],
#      'distance': 942,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Prinsenstraat', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5bb36867345cbe002ca8385e',
#     'name': 'ViaVai Italian Smart Food',
#     'location': {'lat': 52.362862,
#      'lng': 4.911167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.362862,
#        'lng': 4.911167}],
#      'distance': 1924,
#      'postalCode': '1018 WB',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1018 WB Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5aa3d98e65cdf87dfb97ecbf',
#     'name': 'Delicious Food Organic',
#     'location': {'lat': 52.378891,
#      'lng': 4.885562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.378891,
#        'lng': 4.885562}],
#      'distance': 1020,
#      'postalCode': '1015 MJ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1015 MJ Amsterdam', 'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5ad34b154a1cc0082b41edef',
#     'name': 'Vegan Junk Food Bar',
#     'location': {'lat': 52.36288978983606,
#      'lng': 4.928249936507418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36288978983606,
#        'lng': 4.928249936507418}],
#      'distance': 2591,
#      'postalCode': '1093 GJ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['1093 GJ Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4c48893396abd13a7fb37401',
#     'name': "Warie's Thai Food",
#     'location': {'address': 'Rozengracht 235',
#      'lat': 52.372324080414124,
#      'lng': 4.876371534500915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.372324080414124,
#        'lng': 4.876371534500915}],
#      'distance': 1800,
#      'postalCode': '1016',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Rozengracht 235', '1016 Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '58620945'},
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4d9eea8236818cfa6108fe00',
#     'name': 'Strawberryfrog Food Court',
#     'location': {'lat': 52.373629,
#      'lng': 4.886728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.373629,
#        'lng': 4.886728}],
#      'distance': 1109,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5320435a498e96a03811f6e0',
#     'name': 'food town',
#     'location': {'lat': 52.36648178100586,
#      'lng': 4.890669822692871,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36648178100586,
#        'lng': 4.890669822692871}],
#      'distance': 1537,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5909c633b3c9615c9b04d95b',
#     'name': 'Vegan Junk Food Bar',
#     'location': {'address': 'Staringplein 22',
#      'lat': 52.360430698577986,
#      'lng': 4.86325608321129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.360430698577986,
#        'lng': 4.86325608321129}],
#      'distance': 3265,
#      'postalCode': '1054 VJ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Staringplein 22',
#       '1054 VJ Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5744ab0f498e1410e6bfb9c1',
#     'name': 'Food Corner',
#     'location': {'lat': 52.382073,
#      'lng': 4.878887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.382073,
#        'lng': 4.878887}],
#      'distance': 1515,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4ccc19ae566aa093b5001ffd',
#     'name': 'Fast Food',
#     'location': {'lat': 52.37830023767907,
#      'lng': 4.8828604540130165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37830023767907,
#        'lng': 4.8828604540130165}],
#      'distance': 1205,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4b93ee7ef964a520b85a34e3',
#     'name': 'eetcafe fast-food',
#     'location': {'address': 'Westerstraat 134',
#      'lat': 52.378332,
#      'lng': 4.882862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.378332,
#        'lng': 4.882862}],
#      'distance': 1205,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Westerstraat 134', 'Amsterdam', 'Nederland']},
#     'categories': [],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5474b101498eccc2dc2ae08a',
#     'name': 'Jumbo Foodmarkt',
#     'location': {'address': 'Gedempt Hamerkanaal 223',
#      'lat': 52.383126005939026,
#      'lng': 4.919943909081107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.383126005939026,
#        'lng': 4.919943909081107}],
#      'distance': 1397,
#      'postalCode': '1021 KP',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Gedempt Hamerkanaal 223',
#       '1021 KP Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '4c6eac1410faa143a45bf168',
#     'name': 'Food',
#     'location': {'lat': 52.379031,
#      'lng': 4.863494,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.379031,
#        'lng': 4.863494}],
#      'distance': 2520,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False},
#    {'id': '5426aaed498e51a58d410874',
#     'name': 'Foodhallen',
#     'location': {'address': 'Bellamyplein 51',
#      'lat': 52.36694440796742,
#      'lng': 4.868240438050978,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.36694440796742,
#        'lng': 4.868240438050978}],
#      'distance': 2569,
#      'postalCode': '1053 AT',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Bellamyplein 51',
#       '1053 AT Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564405836',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 3  [{'id': '50be8ee891d4fa8dcc7199a7', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
#
#                          id             location.address location.cc  \
# 0  504dc9f3e4b00c01095766a0                   Dam Square          NL
# 1  5877c5c1e9dad12ac9e9aa0e      1e Constantijn Huijgens          NL
# 2  52d7ec76498e19770b7d649b                 Stormsteeg 8          NL
# 3  4c9f2aa103133704e7ca6fd5        Jan van Galenstraat 4          NL
# 4  5cbb2697c876c80039d5e8d3  Nieuwezijds Voorburgwal 182          NL
#
#   location.city location.country location.crossStreet  location.distance  \
# 0           NaN        Nederland                  NaN                748
# 1     Amsterdam        Nederland             Overtoom               2490
# 2     Amsterdam        Nederland                  NaN                655
# 3     Amsterdam        Nederland                  NaN               2267
# 4     Amsterdam        Nederland                  NaN                876
#
#                            location.formattedAddress  \
# 0                            [Dam Square, Nederland]
# 1  [1e Constantijn Huijgens (Overtoom), Amsterdam...
# 2       [Stormsteeg 8, 1012 BD Amsterdam, Nederland]
# 3  [Jan van Galenstraat 4, 1051 KM Amsterdam, Ned...
# 4  [Nieuwezijds Voorburgwal 182, 1012 SJ Amsterda...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 52.37352715384458...     52.373527
# 1  [{'label': 'display', 'lat': 52.36285262494781...     52.362853
# 2  [{'label': 'display', 'lat': 52.37406002111417...     52.374060
# 3  [{'label': 'display', 'lat': 52.3762512, 'lng'...     52.376251
# 4  [{'label': 'display', 'lat': 52.373764, 'lng':...     52.373764
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0      4.893949                   NaN                 NaN            NaN
# 1      4.875043                   NaN                 NaN  Noord-Holland
# 2      4.895095                   NaN             1012 BD  Noord-Holland
# 3      4.867490                   NaN             1051 KM  Noord-Holland
# 4      4.890815                   NaN             1012 SJ  Noord-Holland
#
#                     name    referralId venuePage.id
# 0            Food Corner  v-1564405836          NaN
# 1            STACH  food  v-1564405836          NaN
# 2          St. Anny Food  v-1564405836          NaN
# 3  Food Center Amsterdam  v-1564405836          NaN
# 4    The Food Department  v-1564405836    545894791

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                              name                     categories  \
# 0                     Food Corner                     Food Court
# 1                     STACH  food                   Gourmet Shop
# 2                   St. Anny Food                         Bakery
# 3           Food Center Amsterdam                         Market
# 4             The Food Department                     Food Court
# 5                      STACH Food                Organic Grocery
# 6           PLAYERS Food & Drinks                     Restaurant
# 7  Homemade - Fresh Food & Drinks                 Sandwich Place
# 8                      Halal Food             Falafel Restaurant
# 9             Vegan Junk Food Bar  Vegetarian / Vegan Restaurant
#
#                        address  cc       city    country  \
# 0                   Dam Square  NL        NaN  Nederland
# 1      1e Constantijn Huijgens  NL  Amsterdam  Nederland
# 2                 Stormsteeg 8  NL  Amsterdam  Nederland
# 3        Jan van Galenstraat 4  NL  Amsterdam  Nederland
# 4  Nieuwezijds Voorburgwal 182  NL  Amsterdam  Nederland
# 5         Haarlemmerstraat 150  NL  Amsterdam  Nederland
# 6   Kleine Gartmanplantsoen 25  NL  Amsterdam  Nederland
# 7                   Singel 447  NL  Amsterdam  Nederland
# 8                       Damrak  NL  Amsterdam  Nederland
# 9                          NaN  NL  Amsterdam  Nederland
#
#             crossStreet  distance  \
# 0                   NaN       748
# 1              Overtoom      2490
# 2                   NaN       655
# 3                   NaN      2267
# 4                   NaN       876
# 5                   NaN       801
# 6  at Leidsekruisstraat      2087
# 7             Amsterdam      1460
# 8                   NaN       526
# 9                   NaN      1521
#
#                                     formattedAddress  \
# 0                            [Dam Square, Nederland]
# 1  [1e Constantijn Huijgens (Overtoom), Amsterdam...
# 2       [Stormsteeg 8, 1012 BD Amsterdam, Nederland]
# 3  [Jan van Galenstraat 4, 1051 KM Amsterdam, Ned...
# 4  [Nieuwezijds Voorburgwal 182, 1012 SJ Amsterda...
# 5  [Haarlemmerstraat 150, 1013 EZ Amsterdam, Nede...
# 6  [Kleine Gartmanplantsoen 25 (at Leidsekruisstr...
# 7  [Singel 447 (Amsterdam), 1012 WP Amsterdam, Ne...
# 8                     [Damrak, Amsterdam, Nederland]
# 9                     [1017 BE Amsterdam, Nederland]
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 52.37352715384458...  52.373527  4.893949
# 1  [{'label': 'display', 'lat': 52.36285262494781...  52.362853  4.875043
# 2  [{'label': 'display', 'lat': 52.37406002111417...  52.374060  4.895095
# 3  [{'label': 'display', 'lat': 52.3762512, 'lng'...  52.376251  4.867490
# 4  [{'label': 'display', 'lat': 52.373764, 'lng':...  52.373764  4.890815
# 5  [{'label': 'display', 'lat': 52.38139046900278...  52.381390  4.889511
# 6  [{'label': 'display', 'lat': 52.36311062437967...  52.363111  4.884000
# 7  [{'label': 'display', 'lat': 52.36729984225847...  52.367300  4.890536
# 8  [{'label': 'display', 'lat': 52.37524869072558...  52.375249  4.895655
# 9  [{'label': 'display', 'lat': 52.36639117639653...  52.366391  4.891563
#
#         neighborhood postalCode          state                        id
# 0                NaN        NaN            NaN  504dc9f3e4b00c01095766a0
# 1                NaN        NaN  Noord-Holland  5877c5c1e9dad12ac9e9aa0e
# 2                NaN    1012 BD  Noord-Holland  52d7ec76498e19770b7d649b
# 3                NaN    1051 KM  Noord-Holland  4c9f2aa103133704e7ca6fd5
# 4                NaN    1012 SJ  Noord-Holland  5cbb2697c876c80039d5e8d3
# 5                NaN    1013 EZ  Noord-Holland  52a3050011d2ae60be6128a0
# 6                NaN    1017 RP  Noord-Holland  4b3633ddf964a520093125e3
# 7                NaN    1012 WP  Noord-Holland  4ad9d80cf964a520311b21e3
# 8  Stadsdeel Centrum        NaN  Noord-Holland  50a8eeb6e4b0740a188b900d
# 9                NaN    1017 BE  Noord-Holland  5c24d2a0e4c459002c9c4e72

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add a red circle marker to represent the Taj
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Amsterdam Centraal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=SYEWADAPWXPOGCEVE32FQSELE4CBCEABDFCQZKRKHS4NGOHE&client_secret=VEDXRHYYJ1S34VOZZDH3APR5F2PHH32R2WUEMPX51AGUKAWL&ll=52.378901,4.9005805&v=20190729&radius=4000&limit=100'

# %% [markdown]
# ## Get details of venues near Amsterdam Centraal

# %%
import requests

# %%
results = requests.get(url).json()

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '55c10ee5498ecb81fe809f9d',
#   'name': 'Omelegg - City Centre',
#   'location': {'address': 'Nieuwebrugsteeg 24',
#    'crossStreet': 'warmoesstraat',
#    'lat': 52.37606,
#    'lng': 4.899802,
#    'labeledLatLngs': [{'label': 'display', 'lat': 52.37606, 'lng': 4.899802}],
#    'distance': 320,
#    'postalCode': '1012 AH',
#    'cc': 'NL',
#    'city': 'Amsterdam',
#    'state': 'Noord-Holland',
#    'country': 'Nederland',
#    'formattedAddress': ['Nieuwebrugsteeg 24 (warmoesstraat)',
#     '1012 AH Amsterdam',
#     'Nederland']},
#   'categories': [{'id': '4bf58dd8d48988d143941735',
#     'name': 'Breakfast Spot',
#     'pluralName': 'Breakfast Spots',
#     'shortName': 'Breakfast',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '136396172'}},
#  'referralId': 'e-0-55c10ee5498ecb81fe809f9d-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                    name         categories  \
# 0                 Omelegg - City Centre     Breakfast Spot
# 1                              art'otel              Hotel
# 2                             Toastable     Sandwich Place
# 3                               Jacketz         Restaurant
# 4                   SkyLounge Amsterdam          Hotel Bar
# 5                                 Choux         Restaurant
# 6        Bierproeflokaal In de Wildeman                Bar
# 7  Ashoka Restaurant -Amsterdam Centrum  Indian Restaurant
# 8                   De Koffieschenkerij        Coffee Shop
# 9                      Cannibale Royale       Burger Joint
#
#                 address  cc       city    country            crossStreet  \
# 0    Nieuwebrugsteeg 24  NL  Amsterdam  Nederland          warmoesstraat
# 1  Prins Hendrikkade 33  NL  Amsterdam  Nederland     Martelaarsgracht 5
# 2         Nieuwendijk 6  NL  Amsterdam  Nederland                    NaN
# 3        32 Nieuwendijk  NL  Amsterdam  Nederland             Engelsteeg
# 4    Oosterdoksstraat 4  NL  Amsterdam  Nederland                    NaN
# 5    De Ruijterkade 128  NL  Amsterdam  Nederland                    NaN
# 6           Kolksteeg 3  NL  Amsterdam  Nederland                    NaN
# 7         Spuistraat 3G  NL  Amsterdam  Nederland                    NaN
# 8     Oudekerksplein 23  NL  Amsterdam  Nederland  Oudezijds Voorburgwal
# 9       Lange Niezel 15  NL  Amsterdam  Nederland                    NaN
#
#    distance                                   formattedAddress  \
# 0       320  [Nieuwebrugsteeg 24 (warmoesstraat), 1012 AH A...
# 1       271  [Prins Hendrikkade 33 (Martelaarsgracht 5), 10...
# 2       392      [Nieuwendijk 6, 1012 MK Amsterdam, Nederland]
# 3       358  [32 Nieuwendijk (Engelsteeg), 1012 ML Amsterda...
# 4       385  [Oosterdoksstraat 4, 1011 DK Amsterdam, Nederl...
# 5       473  [De Ruijterkade 128, 1011AC Amsterdam, Nederland]
# 6       475        [Kolksteeg 3, 1012 PT Amsterdam, Nederland]
# 7       476      [Spuistraat 3G, 1012 SP Amsterdam, Nederland]
# 8       560  [Oudekerksplein 23 (Oudezijds Voorburgwal), 10...
# 9       449    [Lange Niezel 15, 1012 GS Amsterdam, Nederland]
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 52.37606, 'lng': ...  52.376060  4.899802
# 1  [{'label': 'display', 'lat': 52.37764, 'lng': ...  52.377640  4.897160
# 2  [{'label': 'display', 'lat': 52.37879049945435...  52.378790  4.894805
# 3  [{'label': 'display', 'lat': 52.37822855550258...  52.378229  4.895425
# 4  [{'label': 'display', 'lat': 52.37686021496292...  52.376860  4.905160
# 5  [{'label': 'display', 'lat': 52.37769306062365...  52.377693  4.907260
# 6  [{'label': 'display', 'lat': 52.37622160710857...  52.376222  4.895134
# 7  [{'label': 'display', 'lat': 52.37709413565575...  52.377094  4.894229
# 8  [{'label': 'display', 'lat': 52.37404292238903...  52.374043  4.898427
# 9  [{'label': 'display', 'lat': 52.37503133828516...  52.375031  4.898690
#
#         neighborhood postalCode          state                        id
# 0                NaN    1012 AH  Noord-Holland  55c10ee5498ecb81fe809f9d
# 1                NaN    1012 TM  Noord-Holland  51d532e9e4b098c3c66f49d9
# 2                NaN    1012 MK  Noord-Holland  561e39f5498e059a294a7913
# 3  Stadsdeel Centrum    1012 ML  Noord-Holland  5900ec9898fbfc4fa94b2f39
# 4                NaN    1011 DK  Noord-Holland  4de6588a18389f0558772bbf
# 5                NaN     1011AC  Noord-Holland  55674fe7498e0a4781b0f3d8
# 6                NaN    1012 PT  Noord-Holland  4a26ffccf964a52011811fe3
# 7  Stadsdeel Centrum    1012 SP  Noord-Holland  53e0cca8498ed3c8aa65b287
# 8                NaN    1012 GX  Noord-Holland  51d98583498e78da6626be60
# 9          De Wallen    1012 GS  Noord-Holland  57910d45498eeaf3c1c08128

# %% [markdown]
# Since around 4km in radius Amsterdam Centraal, there are many restaraunts so will try to find most optimal location for it. We would also prefer locations as close to Amsterdam Centraal as possible.We will divide area around Amsterdam Centraal into grids upto 6km radius and try to find ares with least number of restraunts in those grids. Let's create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest which is aprox. 12x12 killometers centered around Amsterdam Centraal.

# %%
centraal = [52.3791, 4.9003]

# %% [markdown]
# Let's create a hexagonal grid of cells: we offset every other row, and adjust vertical row spacing so that every cell center is equally distant from all it's neighborhoods.

# %%
# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('centraal longitude={}, latitude={}'.format(centraal[1], centraal[0]))
x, y = lonlat_to_xy(centraal[1], centraal[0])
print('centraal UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('centraal longitude={}, latitude={}'.format(lo, la))
# Out:
# Collecting shapely
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 2.3MB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.6.4.post2
# Collecting pyproj
#   Downloading https://files.pythonhosted.org/packages/16/59/43869adef45ce4f1cf7d5c3aef1ea5d65d449050abdda5de7a2465c5729d/pyproj-2.2.1-cp36-cp36m-manylinux1_x86_64.whl (11.2MB)
#      |████████████████████████████████| 11.2MB 2.0MB/s eta 0:00:01
# Installing collected packages: pyproj
# Successfully installed pyproj-2.2.1
# Coordinate transformation check
# -------------------------------
# centraal longitude=4.9003, latitude=52.3791
# centraal UTM X=-186556.6743409466, Y=5851350.986540761
# centraal longitude=4.900300000000002, latitude=52.3791

# %%
centraal_x, centraal_y = lonlat_to_xy(centraal[1], centraal[0]) # centraal in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = centraal_x - 6000
x_step = 600
y_min = centraal_y - 6000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(centraal_x, centraal_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 364 candidate neighborhood centers generated.

# %%
#!pip install folium

import folium

# %%
map_centraal = folium.Map(location=centraal, zoom_start=12)
folium.Marker(centraal, popup='Amsterdam Centraal').add_to(map_centraal)
for lat, lon in zip(latitudes, longitudes):
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_centraal)
map_centraal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
google_api_key='AIzaSyB8QdOk3UbmTiC4xoS4nGnM9ZvQYX9nVFk'
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(google_api_key, centraal[0], centraal[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(centraal[0], centraal[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [52.3791, 4.9003] is: None

# %%
google_api_key='AIzaSyB8QdOk3UbmTiC4xoS4nGnM9ZvQYX9nVFk'
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Germany', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head(10)
# Out:
#       Address   Latitude  Longitude              X             Y  \
# 0  NO ADDRESS  52.326262   4.885943 -188356.674341  5.845635e+06
# 1  NO ADDRESS  52.327012   4.894610 -187756.674341  5.845635e+06
# 2  NO ADDRESS  52.327761   4.903278 -187156.674341  5.845635e+06
# 3  NO ADDRESS  52.328509   4.911946 -186556.674341  5.845635e+06
# 4  NO ADDRESS  52.329257   4.920615 -185956.674341  5.845635e+06
# 5  NO ADDRESS  52.330004   4.929283 -185356.674341  5.845635e+06
# 6  NO ADDRESS  52.330750   4.937953 -184756.674341  5.845635e+06
# 7  NO ADDRESS  52.329736   4.871882 -189256.674341  5.846155e+06
# 8  NO ADDRESS  52.330486   4.880549 -188656.674341  5.846155e+06
# 9  NO ADDRESS  52.331236   4.889217 -188056.674341  5.846155e+06
#
#    Distance from center
# 0           5992.495307
# 1           5840.376700
# 2           5747.173218
# 3           5715.767665
# 4           5747.173218
# 5           5840.376700
# 6           5992.495307
# 7           5855.766389
# 8           5604.462508
# 9           5408.326913

# %%
df_locations.shape
# Out:
# (364, 6)

# %%
df_locations.to_pickle('./locations.pkl')

# %%
food_category = '4d4b7105d754a06374d81259' # 'Root' category for all food-related venues

def is_restaurant(categories, specific_filter=None):
    restaurant_words = ['restaurant', 'diner', 'taverna', 'steakhouse']
    restaurant = False
    specific = False
    for c in categories:
        category_name = c[0].lower()
        category_id = c[1]
        for r in restaurant_words:
            if r in category_name:
                restaurant = True
        if 'fast food' in category_name:
            restaurant = False
        if not(specific_filter is None) and (category_id in specific_filter):
            specific = True
            restaurant = True
    return restaurant, specific

def get_categories(categories):
    return [(cat['name'], cat['id']) for cat in categories]

def format_address(location):
    address = ', '.join(location['formattedAddress'])
    address = address.replace(', India', '')
    return address

def get_venues_near_location(lat, lon, category, CLIENT_ID, CLIENT_SECRET, radius=500, limit=100):
    version = '20180729'
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, version, lat, lon, category, radius, limit)
    try:
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues = [(item['venue']['id'],
                   item['venue']['name'],
                   get_categories(item['venue']['categories']),
                   (item['venue']['location']['lat'], item['venue']['location']['lng']),
                   format_address(item['venue']['location']),
                   item['venue']['location']['distance']) for item in results]        
    except:
        venues = []
    return venues

# %%
import pickle

def get_restaurants(lats, lons):
    restaurants = {}
    location_restaurants = []

    print('Obtaining venues around candidate locations:', end='')
    for lat, lon in zip(lats, lons):
        # Using radius=350 to meke sure we have overlaps/full coverage so we don't miss any restaurant (we're using dictionaries to remove any duplicates resulting from area overlaps)
        venues = get_venues_near_location(lat, lon, food_category, CLIENT_ID, CLIENT_SECRET, radius=350, limit=100)
        area_restaurants = []
        for venue in venues:
            venue_id = venue[0]
            venue_name = venue[1]
            venue_categories = venue[2]
            venue_latlon = venue[3]
            venue_address = venue[4]
            venue_distance = venue[5]
            is_res = is_restaurant(venue_categories)
            if is_res:
                x, y = lonlat_to_xy(venue_latlon[1], venue_latlon[0])
                restaurant = (venue_id, venue_name, venue_latlon[0], venue_latlon[1], venue_address, venue_distance, x, y)
                if venue_distance<=300:
                    area_restaurants.append(restaurant)
                restaurants[venue_id] = restaurant
        location_restaurants.append(area_restaurants)
        print(' .', end='')
    print(' done.')
    return restaurants, location_restaurants

# Try to load from local file system in case we did this before
restaurants = {}
location_restaurants = []
loaded = False
try:
    with open('restaurants_350.pkl', 'rb') as f:
        restaurants = pickle.load(f)
    with open('location_restaurants_350.pkl', 'rb') as f:
        location_restaurants = pickle.load(f)
    print('Restaurant data loaded.')
    loaded = True
except:
    pass

# If load failed use the Foursquare API to get the data
if not loaded:
    restaurants, location_restaurants = get_restaurants(latitudes, longitudes)
    
    # Let's persists this in local file system
    with open('restaurants_350.pkl', 'wb') as f:
        pickle.dump(restaurants, f)
    with open('location_restaurants_350.pkl', 'wb') as f:
        pickle.dump(location_restaurants, f)
# Out:
# Obtaining venues around candidate locations: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
import numpy as np

print('Total number of restaurants:', len(restaurants))
print('Average number of restaurants in neighborhood:', np.array([len(r) for r in location_restaurants]).mean())
# Out:
# Total number of restaurants: 2156
# Average number of restaurants in neighborhood: 5.293956043956044

# %% [markdown]
# ## Analysis
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's count **the number of restaurants in every area candidate**:

# %%
location_restaurants_count = [len(res) for res in location_restaurants]

df_locations['Restaurants in area'] = location_restaurants_count

print('Average number of restaurants in every area with radius = 300m:', np.array(location_restaurants_count).mean())

df_locations.head(10)
# Out:
# Average number of restaurants in every area with radius = 300m: 5.293956043956044
#       Address   Latitude  Longitude              X             Y  \
# 0  NO ADDRESS  52.326262   4.885943 -188356.674341  5.845635e+06
# 1  NO ADDRESS  52.327012   4.894610 -187756.674341  5.845635e+06
# 2  NO ADDRESS  52.327761   4.903278 -187156.674341  5.845635e+06
# 3  NO ADDRESS  52.328509   4.911946 -186556.674341  5.845635e+06
# 4  NO ADDRESS  52.329257   4.920615 -185956.674341  5.845635e+06
# 5  NO ADDRESS  52.330004   4.929283 -185356.674341  5.845635e+06
# 6  NO ADDRESS  52.330750   4.937953 -184756.674341  5.845635e+06
# 7  NO ADDRESS  52.329736   4.871882 -189256.674341  5.846155e+06
# 8  NO ADDRESS  52.330486   4.880549 -188656.674341  5.846155e+06
# 9  NO ADDRESS  52.331236   4.889217 -188056.674341  5.846155e+06
#
#    Distance from center  Restaurants in area
# 0           5992.495307                    7
# 1           5840.376700                    1
# 2           5747.173218                    0
# 3           5715.767665                    1
# 4           5747.173218                    0
# 5           5840.376700                    3
# 6           5992.495307                    3
# 7           5855.766389                    4
# 8           5604.462508                   13
# 9           5408.326913                    6

# %%
df=df_locations[(df_locations['Restaurants in area'] == 0) & (df_locations['Distance from center']<=1500)].reset_index()
df.drop('index',inplace=True,axis=1)
df
# Out:
#       Address   Latitude  Longitude              X             Y  \
# 0  NO ADDRESS  52.387173   4.885160 -187456.674341  5.852390e+06
# 1  NO ADDRESS  52.387923   4.893839 -186856.674341  5.852390e+06
# 2  NO ADDRESS  52.388673   4.902519 -186256.674341  5.852390e+06
# 3  NO ADDRESS  52.389422   4.911199 -185656.674341  5.852390e+06
#
#    Distance from center  Restaurants in area
# 0           1374.772708                    0
# 1           1081.665383                    0
# 2           1081.665383                    0
# 3           1374.772708                    0

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Taj

# add a red circle marker to represent the Taj
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Amsterdam Centraal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants candidants as blue circle markers
for lat, lng in zip(df.Latitude, df.Longitude):
    folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results
#
# Our analysis shows that there are many restraunts near Amsterdam Centraal and we were mainly concerned about finding best suitable location that is not already crowded with restraunts and is nearest to Amsterdam Centraal. Total number (~2156 in our initial area of interest which was 12x12km around Amsterdam Centraal), there are large pockets of low restraunt density fairly close to Amsterdam Centraal. Highest concentration of restraunts was detected north from Amsterdam Centraal, so we found out the neighbourhoods with no restaraunt and distance from Amsterdam Centraal less than 1.5 km and found out 4 such suitable neighbourhoods.
#
# Result of all these zones containing largest number of potential new restraunt location. Purpose of this analysis was to provide information on areas close to Amsterdam Centraal.It is entirely possible that there is a very good reason for small number of restaraunts in any of those areas, reasons which would make them unsuitable for a new restaurant regardless of lack of competition in the area. Recommended zones should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ## Conclusion
# Purpose of this project was to identify Amsterdam areas close to Amsterdam Centraal with low number of restaurants in order to aid stakeholders in narrowing down the search for optimal location for a new restaurant. By calculating restaurant density distribution from Foursquare data we have first identified coordinates and neighbourhoods that justify further analysis and then generated extensive collection of locations which satisfy some basic requirements regarding existing nearby restaurants.Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
